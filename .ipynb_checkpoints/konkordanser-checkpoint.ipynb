# %% [markdown]
# # Undersøk korpus med metadata og konkordans
#
# Konkordanser gir oppslagt for nøkkelord i en kontekst, også kjent under akronymet [KWIC](https://en.wikipedia.org/wiki/Key_Word_in_Context). Kommandoene som benyttes er get_konk (eller nb.get_konk), og ligger klar i modulen nbtext.
#
# Gjør API-et aktivt ved å kjøre cellen under.

# %%
import nbtext as nb
from nbtext import get_urn, get_konk, get_urnkonk, urn_from_text
# %matplotlib inline

# %% [markdown]
# ## Konkordanser
#
# Det minste som må spesifiseres for kommandoen *get_konk()* er et ord.

# %%
urns = get_urn({'year':1200, 'next':500, 'limit':6000})

# %%
len(urns)
# Out:
# 664

# %%
titles = [x[2] for x in urns]

# %%
titles
# Out:
# ['Sachs, Michael',
#  'Miltzow, Gert Henrikssøn',
#  'Gyldenløve, Ulrik Frederik',
#  'Corthoys, Conrad',
#  "Anghiera, Pietro Martire d'",
#  'Løvenklau, Jørgen',
#  '',
#  'Been, Hans Nielsen',
#  'Arctander, Niels Lauridsen',
#  'Euclides',
#  'Wallis, John',
#  '',
#  'Cort Aslakssøn',
#  'La Martinière, Pierre Martin de',
#  'Been, Hans Nielsen',
#  'Huitfeldt, Arild',
#  'Emmius, Ubbo',
#  'Augustinus, Aurelius',
#  '',
#  'Budé, Guillaume',
#  'Mogensen, Hans',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Castanheda, Fernão Lopes de',
#  'Freitag, Adam',
#  'Fasting, Claus',
#  'Herwigk, Hans',
#  '',
#  'La Martinière, Pierre Martin de',
#  'Ephraem Syrus',
#  'Christen Jensøn',
#  'Bredal, Erik Andersen',
#  'Förtsch, Basilius',
#  'Ruscelli, Girolamo',
#  'Bjelke, Jens',
#  'Freitag, Adam',
#  'Hallvard Gunnarsson',
#  'Jessen, Hannibal',
#  '',
#  'Escholt, Mickel Pedersøn',
#  '',
#  'Pogwisch, Bertram',
#  'Kraglund, Peder Jensen',
#  'Müller, Heinrich',
#  'Dieu, Lodewijk de',
#  'Reineck, Reiner',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Rumpolt, Marx',
#  'Brunsmand, Johan',
#  'Carion, Johann',
#  'Aldrete, Bernardo',
#  'Saxo Grammaticus',
#  'Trundhiemb, Claus Anderssøn',
#  'Lipstorp, Daniel',
#  'Scaliger, Joseph Juste',
#  'Schoonhoven, Florens van',
#  '',
#  'Bertonio, Ludovico',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Brunsmand, Johan',
#  'Mogenssøn, Mikkel',
#  'Huitfeldt, Arild',
#  '',
#  'Rantzau, Henrik',
#  'Leigh, Michael Sørensen',
#  '',
#  'Arctander, Niels Lauridsen',
#  '',
#  'Zeiller, Martin',
#  'Bolling, Frederik',
#  'Ramus, Jonas',
#  'Arctander, Niels Lauridsen',
#  '',
#  '',
#  'Örnhjälm, Claudius',
#  'Cort Aslakssøn',
#  'King, William',
#  'Lassenius, Johan',
#  'Hallvard Gunnarsson',
#  'Hallvard Gunnarsson',
#  'Arndt, Johann',
#  'Arctander, Niels Lauridsen',
#  'Adolph, Iver Pedersen',
#  'Comenius, Jan Amos',
#  'Trolle, Niels',
#  'Paulli, Jacob Henrik',
#  'Poliziano, Angelo',
#  'Cort Aslakssøn',
#  '',
#  'Bloch, Hans Rasmussen',
#  '',
#  '',
#  'Fiaschi, Cesare',
#  'Rousseau de la Valette, Michel',
#  'Einhard',
#  'Brunsmand, Johan',
#  'Savonarola, Girolamo',
#  'Hanssøn, Laurits',
#  'Aqvilonius, Bertel Knudsen',
#  'Kegel, Philipp',
#  'Colonna, Francesco',
#  'Brouwer, Hendrick',
#  'Descartes, René',
#  'Been, Hans Nielsen',
#  'Lassenius, Johan',
#  'Moller, Martin',
#  'Kegel, Philipp',
#  'Bjelke, Jens',
#  'Knoff, Christopher',
#  'Saumaise, Claude',
#  'Warner von Warhuysen, Philotheus',
#  '',
#  'Gjødesen, Jens',
#  'Le Noble, Eustache',
#  'Hemmingsen, Niels',
#  'Wolf, Jens Lauridsen',
#  'Saumaise, Claude',
#  '',
#  'Frandsen, Hans',
#  'Uchteritz, Heinrich von',
#  'Larroque, Matthieu de',
#  'Arctander, Niels Lauridsen',
#  'Aelianus Tacticus',
#  '',
#  'Cypraeus, Hieronymus',
#  'Nielsen, Christen',
#  'Bang, Christen Staphensøn',
#  'Bolling, Frederik',
#  'Tormod Torfæus',
#  'Rosenkrantz, Erik',
#  'Friis, Peder Claussøn',
#  'Müller, Heinrich',
#  'Aristoxenus',
#  'Hofferus, Rochus',
#  'Arctander, Niels Lauridsen',
#  'Bredal, Erik Andersen',
#  'Le Noble, Eustache',
#  'Nicolay, Nicolas de',
#  'Stephanius, Stephen Hansen',
#  'Boey, Cornelis',
#  'Puteanus, Erycius',
#  'Brunsmand, Johan',
#  '',
#  'Aristoteles',
#  'Stockfleth, Henning',
#  'Christopherssøn, Mentz',
#  'Bjelke, Jens',
#  'Lascaris, Constantinus',
#  'La Martinière, Pierre Martin de',
#  'Bodecher Benningh, Johan',
#  '',
#  'Borch, Anders Iversen',
#  'Hardenbeck, Ambrosius',
#  'Dögen, Matthias',
#  'Verelius, Olof',
#  '',
#  'Paulli, Simon',
#  'Brahe, Tycho',
#  '',
#  'Vedel, Anders Sørensen',
#  '',
#  'Dorothe Engelbretsdatter',
#  'Coccejus, Johannes',
#  'La Martinière, Pierre Martin de',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Meurs, Johannes van',
#  'Erikssøn, Jørgen',
#  'Müller, Heinrich',
#  'Palladius Helenopolitanus',
#  'Cort Aslakssøn',
#  'Brunsmand, Johan',
#  'Dieu, Lodewijk de',
#  'Lechuga, Cristoval',
#  'Hemmingsen, Niels',
#  'Wolf, Jens Lauridsen.',
#  'Bang, Christen Staphensøn',
#  'Colding, Niels Nielsen',
#  'Rousseau de la Valette, Michel',
#  'Brinch, Diderik',
#  'Stockfleth, Henning',
#  'Rosenkrantz, Oluf',
#  'Holstenius, Lucas',
#  'Galle, Théodore',
#  'Gallonio, Antonio',
#  'Jensen, Jon',
#  'Thomessøn, Niels',
#  'Lassenius, Johan',
#  'Heinsius, Daniel',
#  'Heinsius, Daniel',
#  'Manutius, Aldus',
#  'Zeiller, Martin',
#  'Stephanius, Stephen Hansen',
#  'Rosing, Hans',
#  'Rhodius, Ambrosius',
#  'Laetus, Erasmus',
#  '',
#  '',
#  'Borch, Anders Iversen',
#  'Küsel, Melchior',
#  'Bang, Christen Staphensøn',
#  '',
#  'Phlegon Trallianus',
#  'Quintilianus, Marcus Fabius',
#  'Been, Hans Nielsen',
#  '',
#  'Lodberg, Christen Jensen',
#  'Pasquier, Étienne',
#  'Brunsmand, Johan',
#  'Apostolius, Michael',
#  '',
#  'Saumaise, Claude',
#  '',
#  '',
#  '',
#  'Been, Hans Nielsen',
#  'Bouelles, Charles de',
#  'Hemmingsen, Niels',
#  'Jørgenssøn, Engebret',
#  'Dögen, Matthias',
#  'Aalborg, Niels Mikkelsen',
#  'Cort Aslakssøn',
#  'Stoud, Ludvig',
#  'Clément de Treille, Nicolas',
#  'Scavenius, Peder Lauridsen',
#  'Brahe, Per',
#  'Schefferus, Johannes',
#  'Laetus, Erasmus',
#  '',
#  'Nyborg, Peder Andersen',
#  'Bartholin, Hans',
#  '',
#  'Huitfeldt, Arild',
#  'Adam Bremensis',
#  'Celsus, Aulus Cornelius',
#  'Arctander, Niels Lauridsen',
#  '',
#  'Vossius, Gerardus Joannes',
#  'Drexel, Jeremias',
#  'Rousseau de la Valette, Michel',
#  'Pindarus',
#  'Galilei, Galileo',
#  'Procopius Gazaeus',
#  'Ulfeldt, Corfitz',
#  'Purrivus, Christopher',
#  'Comenius, Jan Amos',
#  'Ælnoth',
#  'Münster, Sebastian',
#  'Chiaramonti, Scipione',
#  'Bang, Christen Staphensøn',
#  'Bekker, Balthasar',
#  '',
#  'Rasch, Jacob',
#  'Brunsmand, Johan',
#  '',
#  'Laet, Johannes de',
#  'Laet, Jean de',
#  'Brahe, Tycho',
#  'Been, Hans Nielsen',
#  'Bircherod, Jens',
#  'Wak, Mohammad Enam',
#  'Cort Aslakssøn',
#  'Schrijver, Pieter',
#  'Hrabanus Maurus',
#  '',
#  'Ames, William',
#  'Licques, David',
#  'Sachs, Michael',
#  'Arctander, Niels Lauridsen',
#  'Janus Pannonius',
#  '',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Bartholin, Thomas',
#  'Meng, Hans',
#  'Gassendi, Pierre',
#  'Spelman, John',
#  'Schurtzfleisch, Conrad Samuel',
#  'Wecker, Anna',
#  'Arctander, Niels Lauridsen',
#  'Arrebo, Anders Christensen',
#  '',
#  'Brunsmand, Johan',
#  'Dietrich, Veit',
#  'Snorri Sturluson',
#  'Hemmingsen, Niels',
#  'Worm, Willum',
#  'Vedel, Anders Sørensen',
#  'Kegel, Philipp',
#  'Brunsmand, Johan',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  '',
#  'Cunaeus, Petrus',
#  '',
#  'Rhijne, Willem ten',
#  'Hemmingsen, Niels',
#  'Hemmingsen, Niels',
#  'Chronich, Niels Svendsen',
#  'Hemmingsen, Niels',
#  'Rasch, Jacob',
#  'Jeshua ben Joseph ha-Levi',
#  '',
#  'Erasmus Roterodamus',
#  'Arctander, Niels Lauridsen',
#  'Bang, Christen Staphensøn',
#  'Aeschylus',
#  'Asconius Pedianus, Quintus',
#  '',
#  'Hallvard Gunnarsson',
#  'Brunsmand, Johan',
#  'Vossius, Gerardus Joannes',
#  'Bang, Christen Staphensøn',
#  'Arctander, Niels Lauridsen',
#  'Mumme, Gert',
#  'Hoffmann, Jens Søffrensøn',
#  'Randulff, Niels',
#  '',
#  'Livius, Titus',
#  'Muus, Christian',
#  'Hemmingsen, Niels',
#  '',
#  'Hemmingsen, Niels',
#  'Ricci, Bartolomeo',
#  '',
#  'Clüver, Philipp',
#  'Nyborg, Peder Andersen',
#  'Nielsen, Laurids',
#  'Paradin, Guillaume',
#  'Been, Hans Nielsen',
#  'Worm, Ole',
#  'Wandal, Bagge',
#  'Joannes Chrysostomus',
#  'Alhazen',
#  'La Martinière, Pierre Martin de',
#  'Bang, Christen Staphensøn',
#  'Huitfeldt, Arild',
#  'Buno, Johannes',
#  'Bang, Christen Staphensøn',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Meurs, Johannes van',
#  'Biørnsøn, Michel',
#  'Vegetius Renatus, Flavius',
#  'Skonning, Hans Hansen',
#  'Arctander, Niels Lauridsen',
#  'Vedel, Anders Sørensen',
#  'Borch, Peder Ivarssøn',
#  '',
#  'Serenus, Quintus',
#  'Bredal, Erik Andersen',
#  '',
#  'Wendt, Georg von',
#  'Scheiner, Christoph',
#  'Berg, Christopher',
#  'Arngrímur Jónsson',
#  'Tønder, Oluf',
#  'Arctander, Niels Lauridsen',
#  'Fabris, Salvator',
#  'Streinnius, Richardus',
#  'Goltz, Hubert',
#  'Skonning, Hans Hansen',
#  'Merula, Paulus',
#  'Bartholin, Thomas',
#  'Mirandula, Octavianus',
#  'Bang, Christen Staphensøn',
#  'Sørensen, Zacharias',
#  '',
#  'Boltz von Ruffach, Valentin',
#  '',
#  'Bartholin, Thomas',
#  'Joël, Franz',
#  'Been, Hans Nielsen',
#  'Brunsmand, Johan',
#  'Cort Aslakssøn',
#  'Absalon',
#  'Machiavelli, Niccolò',
#  'Pedersen, Morten',
#  'Arctander, Niels Lauridsen',
#  'Stoud, Ludvig',
#  'Descartes, René',
#  '',
#  'Aqvilonius, Bertel Knudsen',
#  'Laetus, Erasmus',
#  'Saumaise, Claude',
#  'Nielsen, Laurids',
#  'Brahe, Tycho',
#  'Telesio, Bernardino',
#  'Agricola, Rudolf',
#  'Brunsmand, Johan',
#  'Skov, Hans',
#  '',
#  'Dorothe Engelbretsdatter',
#  'Arctander, Niels Lauridsen',
#  'Martialis, Marcus Valerius',
#  'Zeiller, Martin',
#  '',
#  '',
#  'Arctander, Niels Lauridsen',
#  'Schefferus, Johannes',
#  'Erasmus Roterodamus',
#  'Golius, Jacobus',
#  'Hemmingsen, Niels',
#  'Rosing, Hans',
#  'Modius, Franciscus',
#  'Ramus, Jonas',
#  'Hemmingsen, Niels',
#  'Winstrup, Peder Pedersen',
#  'Dorothe Engelbretsdatter',
#  'Tasso, Torquato',
#  'Sachs, Michael',
#  'Macer, Floridus',
#  'Dietrich, Veit',
#  'Laetus, Erasmus',
#  'Ramus, Jonas',
#  '',
#  '',
#  'Arctander, Niels Lauridsen',
#  'Olafsøn, Burge',
#  'Escholt, Mickel Pedersøn',
#  '',
#  'Albrecht, Georg',
#  'Huitfeldt, Arild',
#  '',
#  'Clüver, Philipp',
#  'Erasmus Roterodamus',
#  'Stephanius, Stephen Hansen',
#  'Sperling, Otto',
#  'Muus, Christian',
#  '',
#  'Bosio, Antonio',
#  'Elverfeld, Jonas von',
#  'Buntzow, Niels Mathissøn',
#  '',
#  'Capell, Rudolf',
#  'Heldvad, Niels',
#  'Aalborg, Niels Mikkelsen',
#  'Borchmann, Ole',
#  'Rösslin, Eucharius',
#  'Christopherssøn, Mentz',
#  'Cort Aslakssøn',
#  'Adolph, Iver Pedersen',
#  'Arctander, Niels Lauridsen',
#  'Amama, Sixtinus',
#  'Marbodus Redonensis',
#  'Chronich, Niels Svendsen.',
#  'Voet, Gijsbert',
#  'Spangenberg, Cyriacus',
#  'Caesar, Gaius Julius',
#  'Baïf, Lazare de',
#  'Þórdur Þorláksson',
#  'Ferraro, Pirro Antonio',
#  '',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Arctander, Niels Lauridsen',
#  'La Martinière, Pierre Martin de',
#  'Munk, Jens',
#  'Stockfleth, Henning',
#  '',
#  'Jensen, Laurids',
#  'Forbes, John',
#  'Qvirsfeld, Johann',
#  'Foss, Matthias',
#  'Lerke, Cornelius',
#  'Brochmand, Jesper Rasmussen.',
#  'Elverfeld, Jonas von',
#  'Arndt, Johann',
#  'Küsel, Melchior',
#  'Arctander, Niels Lauridsen',
#  'Rousseau de la Valette, Michel',
#  'Been, Hans Nielsen',
#  'Paulli, Jacob Henrik',
#  'Romanus, Wilhelm',
#  'Hardenbeck, Ambrosius',
#  'Worm, Ole',
#  'Daillé, Jean',
#  'Plato',
#  'Qvirsfeld, Johann',
#  'Saumaise, Claude',
#  '',
#  'Theodorus, Jacobus',
#  'Hallvard Gunnarsson',
#  'Solinus, Gaius Julius',
#  'Ibn ʿArabshāh, Aḥmad ibn Muḥammad',
#  'Ernhoffer, Sigismund',
#  'Ferrari, Girolamo',
#  'Brunsmand, Johan',
#  'Wolf, Jacob Jacobsen',
#  'Hallvard Gunnarsson',
#  'Arctander, Niels Lauridsen',
#  'Leigh, Michael Sørensen',
#  'Pinder, Ulrich',
#  'Joël, Franz',
#  'Boxhorn, Marcus Zuerius',
#  'Hallvard Gunnarsson',
#  'Rutgers, Johannes',
#  'Buchanan, George',
#  'Arctander, Niels Lauridsen',
#  'Arctander, Niels Lauridsen',
#  'Chant, Falquor Alexandersøn',
#  'Heinsius, Nicolaas',
#  'Kock, Oluf',
#  'Luther, Martin',
#  'Clamanges, Nicolas de',
#  'Brunsmand, Johan',
#  'Tybo, Anders Kieldssøn',
#  'Gaas, Hans Claussøn',
#  'Stoud, Ludvig',
#  'Been, Hans Nielsen',
#  '',
#  'Kegel, Philipp',
#  'Brunsmand, Johan',
#  'Hardenbeck, Ambrosius',
#  'Descartes, René',
#  '',
#  'Hotman, François',
#  'Heinsius, Daniel',
#  'Sulpicius Severus',
#  'Ussher, James',
#  'Apollonius Rhodius',
#  'Kingo, Thomas',
#  '',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Svegning, Peder Olufssøn',
#  'Hansen, Søren',
#  'Müller, Heinrich',
#  'Rosing, Rasmus',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  '',
#  'Jacobus Magdalius',
#  '',
#  'Hemmingsen, Niels',
#  'Judichær, Søren Poulsen',
#  'Syv, Peder',
#  'Almeloveen, Theodor Jansson van',
#  '',
#  'Müller, Heinrich',
#  'Christopherssøn, Mentz',
#  'Pontanus, Johan Isaksen',
#  'Bèze, Théodore de',
#  'Praet, Simon à',
#  'Descartes, René',
#  'Joannes de Sacro Bosco',
#  '',
#  'Cunaeus, Petrus',
#  'Brunsmand, Johan',
#  '',
#  'Aitinger, Johann Conrad',
#  '',
#  'Hemmingsen, Niels',
#  'Le Noble, Eustache',
#  'Bang, Christen Staphensøn',
#  'Tormod Torfæus',
#  'Brochmand, Jesper Rasmussen',
#  'Arctander, Niels Lauridsen',
#  'Fasting, Claus',
#  '',
#  'Copernicus, Nicolaus',
#  'Munch, Jens Pedersen',
#  '',
#  'Melanchthon, Philipp',
#  'Tønder, Oluf',
#  'Aretino, Pietro',
#  'Bang, Christen Staphensøn',
#  'Hemmingsen, Niels',
#  'Bolling, Frederik',
#  'Huitfeldt, Arild',
#  'Jespersøn, Peter',
#  'Arctander, Niels Lauridsen',
#  'Irgens, Joachim',
#  'Quarles, Francis',
#  'Snorri Sturluson',
#  'Arctander, Niels Lauridsen',
#  'Swartius, Eusthatius',
#  'Steno, Nicolaus',
#  'Hallvard Gunnarsson',
#  'Rhodius, Ambrosius',
#  'Vinstrup, Peder Jensen',
#  'Luther, Martin',
#  '',
#  'Skov, Hans',
#  '',
#  'Pontanus, Johan Isaksen',
#  'Berntsen, Arent',
#  'Dorothe Engelbretsdatter',
#  'Bang, Christen Staphensøn',
#  'Erasmus Roterodamus',
#  'Eitzen, Paul von',
#  'Olaus Magnus',
#  'Aqvilonius, Bertel Knudsen',
#  '',
#  'Hemmingsen, Niels',
#  'Ramus, Jonas',
#  '',
#  'Wandal, Hans',
#  'Hardenbeck, Ambrosius',
#  'Amyraut, Moïse',
#  'Kraglund, Peder Jensen',
#  'Been, Hans Nielsen',
#  'Erasmus Roterodamus',
#  'Stockfleth, Henning',
#  'Schefferus, Johannes',
#  '',
#  'Linschoten, Jan Huygen van',
#  'Hallvard Gunnarsson',
#  '',
#  '',
#  'Brunsmand, Johan',
#  'Huitfeldt, Arild',
#  'Bang, Christen Staphensøn',
#  'Maccovius, Johannes',
#  'Zeiller, Martin',
#  'Hemmingsen, Niels',
#  'Laet, Johannes de',
#  'Goldmann, Nikolaus',
#  'Bugge, Samuel',
#  'Brinch, Peder Jacobsen',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Huitfeldt, Arild',
#  'Hallvard Gunnarsson',
#  'Huitfeldt, Arild',
#  '',
#  'Brunsmand, Johan',
#  'Jugel, Caspar',
#  'Molesworth, Robert',
#  'Brunsmand, Johan',
#  'Pontanus, Johan Isaksen',
#  'Lauridsen, Anders',
#  'Huitfeldt, Arild',
#  'Qvislin, Laurids Ibsøn',
#  'Martens, Friedrich',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Cicero, Marcus Tullius',
#  'Paulli, Jacob Henrik',
#  'Miltzow, Jens',
#  'Laetus, Erasmus',
#  '',
#  'Jespersen, Niels',
#  '',
#  'Sachs, Michael',
#  'Hulsius, Levinus',
#  'Bang, Christen Staphensøn',
#  'Friis, Peder Claussøn',
#  'Munk, Kirstine',
#  'Courcelles, Étienne de',
#  'Brochmand, Jesper Rasmussen',
#  'Amman, Jost',
#  'Kingo, Thomas',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Nielsen, Laurids',
#  'Laetus, Erasmus',
#  'Karlstadt, Andreas Rudolff-Bodenstein von',
#  'Offvid, Peder Matthissøn',
#  'Wegner, Thomas Cortzsøn',
#  'Cort Aslakssøn',
#  '',
#  'Brunsmand, Johan',
#  'Herdal, Jens Mogenssøn',
#  'Müller, Heinrich',
#  'La Martinière, Pierre Martin de',
#  '',
#  'Sadolin, Hans Jørgensen',
#  'Marulić, Marko',
#  'Nyborg, Peder Andersen',
#  '',
#  'Vedel, Anders Sørensen',
#  'Horatius Flaccus, Quintus',
#  'Wingaard, Mogens',
#  'Heinsius, Daniel']

# %%
get_konk('arbeid')

# %% [markdown]
# Kommandoen *get_konk()* tar parametre for å begrense søket - noen er satt opp med defaultverdier. Parametrene er en måte spesifisere et korpus på, men se nedenfor for andre måter å gjøre akkurat det på.

# %%
get_konk('arbeid', {'size':10, 'corpus':'bok', 'before':8, 'after':8, 'author':'hamsun%'})

# %% [markdown]
# ### Samme konk mot aviser  (kan ta litt tid)

# %% [markdown]
# Bøker og aviser deler litt på egenskaper. Foruten årstall vil for eksempel 'title' gjøre begrensing på boktitler for bøker, og avisnavn for aviser. Årstall begrenser utgivelsesår.

# %%
get_konk('arbeid', {'size':5, 'title':'aftenposten','corpus':'avis', 'yearfrom':1950, 'yearto':1955})

# %% [markdown]
# ## Bygg et korpus av bøker
#
# Får å bygge et korpus av bøker (aviser er i kjømda) brukes kommandoen *get_urn()* med nesten de samme parametrene som for *get_konk()*.
#
# Man kan også finne URN-er i bokhylla, eller lage en liste med URN-er i en tekstfil og bruke kommandoen *urn_from_text()*. Se nedenfor.

# %% [markdown]
# #### get_urn()
#
# Kommandoen *get_urn()* gir et tilfeldig utvalg bøker innenfor spesifikasjonene.
# Aktiver cellen under et par ganger for å se effekten.

# %%
nb.get_urn()

# %% [markdown]
# ### Med kriterier
#
# Vanligvis vil vi begrense korpuset til et helt spesifikt sett av bøker. Kriteriene er de vanlige som forfatter, tittel og år, i tillegg kommer kjønn (gender), tema (subject) og Dewey (ddk).
#
# Her settes dataene opp på formen
#
#     navn = definisjon
#     navn
#
# Første linje definerer navnet, andre viser innholdet. Husk å endre *navn* når cellene kopieres!

# %%
krig = nb.get_urn({'gender':'f', 'subject':'krig', 'ddk':'9%', 'year':1950, 'next':50, 'limit':30})
krig

# %%
finnmark = nb.get_urn({'gender':'%', 'subject':'finnmark', 'lang':'nob', 'year':1950, 'next':50,'limit':5})
finnmark

# %%
trønder = nb.get_urn({'gender':'f', 'subject':'trondheim', 'ddk':'9%', 'year':1950, 'next':50,'limit':30})
trønder

# %% [markdown]
# ## Konkordanser med URNer
#
# Kommandoen er *get_urnkonk()* som bruker URNer i stedet for metadata.

# %%
get_urnkonk('soldater', {'urns':krig, 'before':8, 'after':8, 'size':14}, html=True)

# %% [markdown]
# ## URNer fra Bokhylla
#
# Gåt til http://nb.no/search og søk etter bøker. I søkefeltet legger du til ordet 'debugon' - da kommer resultatene med URN-er. Kopier hele siden (f.eks. med ctrl-a) og lim det inn i cellen under mellom de triple hermetegnene.
#
# Etter at teksten (det blir gjerne en hel del) er limt inn og cellen er aktivert, vil URNene ligge i variabelen bokhylla_urn, som så kan brukes sammen med *get_urnkonk()*.
#
# Har du noen URNer liggende i en Word-fil eller lignende, kan det også limes inn.

# %%
bokhylla_urn = """  """
bokhylla_urn = urn_from_text(bokhylla_urn)
bokhylla_urn

# %%
get_urnkonk('Ask',{
    'urns':bokhylla_urn
})
