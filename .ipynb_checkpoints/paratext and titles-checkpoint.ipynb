# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu

# %%
def list_of_list_to_string(LL):
    
    return '\n\n'.join([' '.join([str(x) for x in line]) for line in LL])

# %%
title_len = lambda df: list(map(len, map(lambda x: x.split(), df['title'])))

# %%
nb.word_form('vel')
# Out:
# ['adv normert',
#  'subst nøyt appell ent ub normert',
#  'subst nøyt appell fl ub normert',
#  'subst nøyt appell ubøy normert']

# %%
nb.unigram('paratekst', period=(1950, 2020)).plot()

# %%
def multi_uni(words, period=(1900, 2020), media='bok'):
    import pandas as pd
    res = dict()
    if isinstance(words, str):
        words = words.split()
    for w in words:
        res[w] = nb.unigram(w, period=period, media = media)
        res[w].columns = [w]
    return pd.concat([res[w] for w in res], axis=1)

# %%
punkt = multi_uni(". , i og det er".split()).sum(axis=1)

# %%
((multi_uni('paratekst Paratekst'.split()).sum(axis=1))/punkt).plot(figsize=(15, 8), lw=5);

# %%
urns = nb.book_urn(words=['paratekst', 'Paratekst'], period=(1950, 2020), limit=500)

# %%
pontoppidan = nb.book_urn(author='pontop%')

# %%
mu.printmd(list_of_list_to_string(pontoppidan))
# Out:
# 2009082103040 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring, til de Enfoldiges Nytte 1862
#
# 2008091800030 Pontoppidan, Erik I Jesu navn 1890
#
# 2012083008268 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring til de Enfoldiges Nytte 1871
#
# 2012020308009 Pontoppidan, Erik Sannhet til gudfryktighet 1959
#
# 2008100603007 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring til de Enfoldiges Nytte 1857
#
# 2011050604090 Pontoppidan, Morten Morten Luther 1902
#
# 2013042608050 Pontoppidan, Erik Troens speil, eller Guds Børns Kjendetegn 1878
#
# 2008091800006 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring til de Enfoldiges Nytte 1846
#
# 2014112708006 Pontoppidan, Erik Oanedubme dr Erik Pontoppidan Cilggitusast 1987
#
# 2008073000059 Pontoppidan, Erik Sannhet til gudfryktighet 1996
#
# 2008091800027 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring til de Enfoldiges Nytte 1855
#
# 2016061329001 Pontoppidan, Erik Oanedubme dr. Erik Pontoppidan c̉ilgitusast 1849
#
# 2014061908035 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring 1861
#
# 2010021803062 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring, til de Enfoldiges Nytte 1855
#
# 2008091800002 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring 1845
#
# 2008091800036 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans forklaring 1885
#
# 2011072720018 Pontoppidan, Erik Sandheds Kraft 1880
#
# 2010102605040 Pontoppidan, Knud Retsmedicinske forelæsninger og studier 1908
#
# 2010020103005 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring til de Eenfoldiges Nytte 1834
#
# 2009072801083 Pontoppidan, Erik Udtog af Dr. Erich Pontoppidans Forklaring til de Enfoldiges Nytte 1851

# %%
len(urns)
# Out:
# 91

# %%
mu.printmd(list_of_list_to_string(nb.best_book_urn(word='paratekst', ddk='%')))
# Out:
# 2009010804047 Solhjell, Dag Formidler og formidlet 2001
#
# 2011032206046 Røssaak, Eivind (Sic) 2001
#
# 2011070808020 Hågvar, Yngve Benestad Hele folkets diskurs 2003
#
# 2011071206070 Tveit, Åse Kristine Innganger 2004
#
# 2012082206068  Kulturvern ved bergverk 2010 2011
#
# 2013070906052 Sæter, Gjertrud Diskurser om svigermor 2010
#
# 2011070405178 Brinch, Sara Historietimer for mediesamfunnet 2004
#
# 2008112704047  Innkjøpt 2001
#
# 2016070708147 Engebretsen, Martin Nyheten som hypertekst 2001
#
# 2009031204016 Lothe, Jakob Litteraturvitenskapelig leksikon 1997
#
# 2014051405013 Engebretsen, Martin Nyheten som hypertekst 2001
#
# 2013072208273 Mjør, Ingeborg Barnelitteratur 2012
#
# 2013061106015 Rekdal, Elin Kjønn og retorikk i tekst og teori: Toril Moi 2008
#
# 2009061704015  Blikkfang 2003
#
# 2008020701060 Eco, Umberto Seks turer i fortellingenes skoger 1994
#
# 2016022308204 Nøding, Aina Vittige kameleoner 2007
#
# 2015091506092 Aschim, Anders Bibelen 3.0 2013
#
# 2013080508183 Lykke, Jon I møte mellom ord og bilde 2000
#
# 2013071008053  Teorier om tekst i møte med skolens lese- og skrivepraksiser 2012
#
# 2012062906094  Tekst i vekst 2007

# %% [markdown]
# # Katekismer

# %%
kat = nb.book_urn(title='%atekism%', limit=3000)
chat = nb.book_urn(title='%atechis%', limit=3000)
kat = kat + chat

luther = [x for x in kat if 'Luth' in x[2]]

luther.sort(key=lambda x: len(x[2]), reverse=True)

luther[-1]

luther_df = nb.frame(luther, "urn author title year".split()).sort_values(by='year')

# %%
luther
# Out:
# [[2016052626003,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus, med Børnelærdoms Visitats i Almindelighed, saa og om enfoldigt Skriftemaal med nogle nyttige Spørgsmaal, efter Dr. Mr. Luthers rette Mening, samt Sententser af Guds Ord til Troens Bestyrkelse for de Enfoldige',
#   1849],
#  [2016060348162,
#   'Pontoppidan, Erik',
#   'Sandhed til Gudfrygtighed, i en enfoldig og efter Mulighed kort, dog tilstrækkelig Forklaring over Sal. Dr. Morten Luthers liden Catechismus indeholdende alt det, som den, der vil blive salig, har behov at vide og gjøre',
#   1914],
#  [2009012800139,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus med barnelærdoms visitats og med et stykke om enfoldigt skriftemaal og kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1887],
#  [2013100308079,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus med barnelærdoms visitats og med et stykke om enfoldigt skriftemaal og kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1905],
#  [2010042703032,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats i Almindelighed,  og christelige Spørgesmaal og Svar for dem, som gaa til Guds Bord samt Sentenser af Guds Ord',
#   1852],
#  [2016051048063,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Herrens Bord, samt Sententser af Guds Ord',
#   1859],
#  [2012061308039,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus med Barnelærdoms Visitats, kristelige Spørgsmaal og svar for dem, som gaar til Herrens bord, samt Sentenser af Guds Ord',
#   1892],
#  [2015050748015,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med barnelærdoms visitats, kristelige spørgsmaal og svar for dem, som gaar til Herrens bord, samt sentenser af Guds ord',
#   1886],
#  [2010030903067,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord : samt Sententser af Guds Ord',
#   1852],
#  [2010030903070,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord : samt Sententser af Guds Ord',
#   1854],
#  [2015092829005,
#   'Bang, Christen Staphensøn',
#   'Postilla Catechetica, ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus ved Spørsmaal oc Giensvar : med hosføyede korte Summarier oc Udleggelser',
#   1657],
#  [2010042703023,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds bord, samt Sententser af Guds Ord',
#   1844],
#  [2010042703054,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord, samt Sententser af Guds Ord',
#   1845],
#  [2016110926003,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds bord, samt Sententser af Guds Ord',
#   1845],
#  [2016060926013,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds bord, samt Sententser af Guds ord',
#   1849],
#  [2016061326004,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord, samt Sententser af Guds Ord',
#   1845],
#  [2009082103007,
#   'Luther, Martin',
#   'Dr. M. Luthers lille katechismus, med børnelærdoms visitats og christelige spørgsmaal og svar for dem, som gaae til Guds bord, samt sententser af Guds ord',
#   1860],
#  [2016101926022,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord, samt Sententser af Guds Ord',
#   1845],
#  [2010070503003,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds bord, samt Sententser af Guds ord',
#   1849],
#  [2016061326001,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord, samt Sententser af Guds Ord',
#   1847],
#  [2016061326003,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord, samt Sententser af Guds Ord',
#   1846],
#  [2016050226005,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds bord, samt Sententser af Guds Ord',
#   1850],
#  [2016060926007,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord, samt Sententser af Guds Ord',
#   1850],
#  [2009020600136,
#   'Luther, Martin',
#   'Dr. M. Luthers lille katechismus, med børnelærdoms visitats og christelige spørgsmaal og svar for dem, som gaa til Guds bord, samt sententser af Guds ord',
#   1852],
#  [2014030308487,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus med Barnelærdoms visitas og kristelige Spørsmaal og Svar for dem, som gaar til Guds Bord, samt sentenser af Guds ord',
#   1918],
#  [2016011448098,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus med Barnelærdoms visitas og kristelige Spørsmaal og Svar for dem, som gaar til Guds Bord, samt sentenser af Guds ord',
#   1898],
#  [2014110424002,
#   'Francke, August Hermann',
#   'Katechismus-Prædikener, hvori Luthers liden Kathechismi fem Hovedparter, til en grundig Opbyggelse i den saliggjørende Kristendom, ere forhandlede',
#   1876],
#  [2009020200126,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus, med barnelærdoms visitats og kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1877],
#  [2012050712004,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med et utvalg av skriftsteder og salmevers og en kort oversikt over kirkeåret og gudstjenesten',
#   1929],
#  [2016041248127,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med et utvalg av skriftsteder og salmevers og en kort oversikt over kirkeåret og gudstjenesten',
#   1935],
#  [2016060926010,
#   'Luther, Martin',
#   'Dr. Morten Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds bord',
#   1849],
#  [2015050748019,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med barnelærdoms visitats, kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1888],
#  [2016011848061,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med barnelærdoms visitats, kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1886],
#  [2015050748017,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med barnelærdoms visitats, kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1888],
#  [2009020600082,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus, med barnelærdoms visitats og kristelige spørgsmaal og svar for dem, som gaar til Guds bord',
#   1893],
#  [2009012800140,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med barnelærdoms visitats, kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1892],
#  [2013042608029,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katekismus, med barnelærdoms visitats og kristelige spørgsmaal og svar for dem, som gaar til Herrens bord',
#   1895],
#  [2014062048052,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord',
#   1861],
#  [2010030903078,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord',
#   1857],
#  [2010020103021,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds bord',
#   1844],
#  [2016051048073,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord',
#   1858],
#  [2009020600137,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaae til Guds Bord',
#   1862],
#  [2009020600091,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaa til Guds Bord',
#   1877],
#  [2014062048054,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katechismus, med Børnelærdoms Visitats og christelige Spørgsmaal og Svar for dem, som gaa til Guds Bord',
#   1874],
#  [2009020600077,
#   'Luther, Martin',
#   'Dr. M. Luthers lille katekismus, med barnelærdoms visitats og kristelige spørgsmaal og svar for dem, som gaar til GudsBord',
#   1888],
#  [2009012700055,
#   'Luther, Martin',
#   'Dr. M. Luthers lille Katekismus, med barnelærdoms visitasog kristelige spørsmaal og svar for dem som gaar til Herrensbord',
#   1914],
#  [2013100708185,
#   'Bang, A. Chr.',
#   'Motiver til en ny Udgave af Dr. M. Luthers lille Katekismus og Forklaring over Dr. M. Luthers lille Katekismus',
#   1891],
#  [2015090327002,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1662],
#  [2015102229002,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1652],
#  [2015102229007,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1653],
#  [2015102229004,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1654],
#  [2015102229009,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1653],
#  [2016022629002,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1651],
#  [2015102229008,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1653],
#  [2015102229006,
#   'Bang, Christen Staphensøn',
#   '[Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar]',
#   1652],
#  [2016112829001,
#   'Bang, Christen Staphensøn',
#   'Postilla Catechetica, Ded er: Doct. Martini Lutheri Lidle eller mindre Catechismus Ved Spørsmaal oc Giensuar',
#   1650],
#  [2014060208014,
#   'Spener, Philipp Jakob',
#   'Dr. Philipp Jakob Speners Forklaring over den christelige Lære efter Dr. Martin Luthers lille Katechismus',
#   1864],
#  [2008091800016,
#   'Pontoppidan, Erik',
#   'Dr. M. Luthers katekisme udlagt i spørsmaal og svar til undervisning for de unge om veien til salighed',
#   1891],
#  [2012021308048,
#   'Vellesen, Jonas',
#   'kristelige barnelærdom med bibelhistorie forbundet med forklaring over Luthers lille katekismus',
#   1901],
#  [2016050948016,
#   'Rode, Fr.',
#   'De fem Parter af Luthers Katechismus med en kortfattet Ordforklaring for de første Begyndere',
#   1864],
#  [2010063003022,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus, med Børnelærdoms Visitats i Almindelighed',
#   1849],
#  [2009020600083,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus, med Børnelærdoms Visitats i Almindelighed',
#   1865],
#  [2009020900019,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus, med Børnelærdoms Visitats i Almindelighed',
#   1861],
#  [2010042003006,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus med Børnelærdoms Visitats i Almindelighed',
#   1850],
#  [2010020103006,
#   'Dass, Petter',
#   'Dr. Morten Luthers Lille Catechismus, forfattet i bekvemme Sange, under føielige Melodier',
#   1851],
#  [2010030903086,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus med Børnelærdoms Visitats i Almindelighed',
#   1856],
#  [2010092803007,
#   'Luther, Martin',
#   'D. M. Luthers liden (eller mindre) Catechismus med Børne-Lærdoms Visitats i Almindelighed',
#   1773],
#  [2009071401046,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Catechismus med Børnelærdoms Visitats i Almindelighed',
#   1847],
#  [2010042003008,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus med Børnelærdoms Visitats i Almindelighed',
#   1844],
#  [2010030903083,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus med Børnelærdoms Visitats i Almindelighed',
#   1855],
#  [2014100928001,
#   'Dass, Petter',
#   'Dr. Morten Luthers Lille Catechismus, forfattet i beqvemme Sange, under føielige Melodier',
#   1845],
#  [2016051048008,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katechismus med Børnelærdoms Visitats i Almindelighed',
#   1858],
#  [2009020900020,
#   'Luther, Martin',
#   'Dr. M. Luthers liden (eller mindre) Katekismus med barnelærdoms visitats i almindelighed',
#   1892],
#  [2009012112003,
#   'Dass, Petter',
#   'D. Morten Luthers Liden Catechismus forfatted i beqvemme Sange under føyelige Melodier',
#   1764],
#  [2014111408052,
#   'Spener, Philipp Jakob',
#   'Forklaring over den christelige Lære efter Dr. Martin Luthers lille Katechismus',
#   1864],
#  [2008091800033,
#   'Tandberg, J.',
#   'Forklaring over Luthers lille Katekismus efter Dr. E. Pontoppidan og Sverdrup',
#   1884],
#  [2009072801112,
#   'Luther, Martin',
#   'Dr. Morten Luthers liden Katechismus, med Forklaring, Bibelsteder og Psalmer',
#   1855],
#  [2009072801116,
#   'Wille, Jacob Andreas',
#   'Spørgsmaal til Dr. Morten Luthers Catechismus med tilføiede Anmærkninger',
#   1836],
#  [2010070105035,
#   'Skretting, Aksel',
#   'Kristenlære for barn med salmer ; knyttet til Luthers lille katekisme',
#   1939],
#  [2014063008190,
#   'Farstad, N.P.S.',
#   'Kort forklaring over de fem parter i Dr. M. Luthers lille katekismus',
#   1893],
#  [2014030408039,
#   'Farstad, N.P.S.',
#   'Kort forklaring over de fem parter i Dr. M. Luthers lille katekismus',
#   1901],
#  [2009012203009,
#   'Farstad, N.P.S.',
#   'Kort forklaring over de fem parter i Dr. M. Luthers lillekatekismus',
#   1891],
#  [2010061406024,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med et utvalg av skriftssteder',
#   1907],
#  [2012041808016,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus med et utvalg av skriftssteder',
#   1908],
#  [2007080910011,
#   'Huhn, A.F.',
#   'Prædikener over de hellige ti Bud efter Luthers lille Katekismus',
#   1884],
#  [2009121013003,
#   'Tollefsen, A.',
#   'Lærebog i den kristne barnelærdom efter dr M. Luthers katekismus',
#   1899],
#  [2008091800035,
#   '',
#   'Luthers katekisme udlagt i spørsmaal og svar efter F Pontoppidan',
#   1893],
#  [2009020200138,
#   '',
#   'Skriftord og Salmevers i Tilslutning til Luthers lille Katekisme',
#   1888],
#  [2009081804069,
#   'Saxe, Oluf',
#   'Prøve paa Udkast til Forklaring over Luthers lille Katekisme',
#   1884],
#  [2010070506138,
#   'Sverdrup, J.R.',
#   'Sverdrups forklåring til katekisma etter dr. Martin Luther',
#   1954],
#  [2013061308176,
#   'Vogt, Volrath',
#   'Forklaring af Luthers lille Katekismus efter Pontoppidan',
#   1870],
#  [2012083008263,
#   'Vogt, Volrath',
#   'Forklaring af Luthers lille Katekismus efter Pontoppidan',
#   1866],
#  [2014061608230,
#   'Vogt, Volrath',
#   'Forklaring af Luthers lille Katekismus efter Pontoppidan',
#   1867],
#  [2016091248029,
#   'Lind, Carl',
#   'Katekisationer over Luthers lille Katekismus for Lærere',
#   1879],
#  [2009061704027,
#   'Schønheyder, Lor. W.',
#   'Kort Udvikling af Doktor Morten Luthers lille Katekisme',
#   1877],
#  [2010102906036,
#   'Sverdrup, J.R.',
#   'Sverdrups forklaring til katekismen etter Martin Luther',
#   1948],
#  [2013081908143,
#   'Sverdrup, J.R.',
#   'Sverdrups forklåring til katekisma etter Martin Luther',
#   1940],
#  [2014121208046,
#   'Dächsel, August',
#   'Forklaring over Dr. Martin Luthers lille Katechismus',
#   1887],
#  [2012061308038,
#   'Blom, P.',
#   'Kort Forklaring over Dr. M. Luthers lille Katekisme',
#   1893],
#  [2009012800138,
#   'Blom, P.',
#   'Kort forklaring over Dr. M. Luthers lille katekisme',
#   1892],
#  [2014120308076,
#   'Gidske, Karl',
#   'Kort Kristendomslære efter Luthers lille Katekisme',
#   1904],
#  [2009072801118,
#   'Saxe, Oluf',
#   'Udkast til Forklaring over Luthers lille Katekisme',
#   1885],
#  [2009013000065,
#   'Luther, Martin',
#   'Luthers lille katekisme med bibelord og salmevers',
#   1931],
#  [2013082708144,
#   'Luther, Martin',
#   'Luthers lille katekisme med bibelord og salmevers',
#   1928],
#  [2009020600125,
#   'Pontoppidan, Erik',
#   'Forklaring af Dr. Morten Luthers lille Katekisme',
#   1883],
#  [2008061904121,
#   'Bang, A. Chr.',
#   'Forklaring over Dr. M. Luthers lille katekismus',
#   1924],
#  [2011102708029,
#   'Bang, A. Chr.',
#   'Forklaring over Dr. M. Luthers lille katekismus',
#   1950],
#  [2009020200076,
#   'Borchgrevink, Einar',
#   'Vår barnetro efter Bibelen og Luthers katekisme',
#   1926],
#  [2009012800136,
#   'Bang, A. Chr.',
#   'Forklaring over Dr. M. Luthers lille katekismus',
#   1890],
#  [2013083008160,
#   'Borchgrevink, Einar',
#   'Vår barnetro etter Bibelen og Luthers katekisme',
#   1924],
#  [2009120812005,
#   'Jensen, O.',
#   'Forklaring over Dr. M. Luthers lille katekismus',
#   1892],
#  [2013121908017,
#   'Jensen, O.',
#   'Forklaring over Dr. M. Luthers lille katekismus',
#   1903],
#  [2009081903009,
#   'Nissen, Johan.',
#   'Nissens Samtaler over Luthers lille Katechismus',
#   1865],
#  [2014021308015,
#   'Jensen, O.',
#   'Forklaring til Dr. M. Luthers lille katekismus',
#   1890],
#  [2009121013002,
#   'Jensen, O.',
#   'Forklaring af Dr. M. Luthers lille katekismus',
#   1890],
#  [2008092900044,
#   'Eikenes, Knut',
#   'Vår trudomslære etter Luthers vesle katekisme',
#   1942],
#  [2008091800043,
#   'Moe, Oscar',
#   'Kort Forklaring af Luthers lille Katekismus',
#   1884],
#  [2008042200003,
#   'Magerøy, Nils H.',
#   'Leidetråd i Martin Luthers litle katekisme',
#   1950],
#  [2007010401056,
#   'Eikenes, Knut',
#   'Vår troslære etter Luthers lille katekisme',
#   1940],
#  [2010062903001,
#   'Rode, Fr.',
#   'Forklaring til Dr. M. Luthers Catechismus',
#   1840],
#  [2013081908144,
#   'Laache, N.J.',
#   'Forklaring over Luthers lille katekismus',
#   1940],
#  [2010031213004,
#   'Meyer, C.L.E.',
#   'Forklaring over Luthers lille katekismus',
#   1892],
#  [2014031808032,
#   'Landstad, Hans',
#   'Forklaring over Luthers lille Katekismus',
#   1894],
#  [2012050708049,
#   'Laache, N.J.',
#   'Forklaring over Luthers lille katekismus',
#   1936],
#  [2013030608057,
#   'Laache, N.J.',
#   'Forklaring over Luthers lille katekismus',
#   1982],
#  [2012083008269,
#   'Meyer, C.L.E.',
#   'Forklaring over Luthers lille katekismus',
#   1894],
#  [2009120212002,
#   'Meyer, C.L.E.',
#   'Forklaring over Luthers lille katekismus',
#   1892],
#  [2013042608137,
#   'Laache, N.J.',
#   'Forklaring over Luthers lille katekismus',
#   1892],
#  [2015062608017,
#   'Meyer, C.L.E.',
#   'Forklaring over Luthers lille katekismus',
#   1893],
#  [2015062208124,
#   'Laache, N.J.',
#   'Forklaring over Luthers lille katekismus',
#   1925],
#  [2006082200013,
#   'Laache, N.J.',
#   'Forklaring over Luthers lille katekismus',
#   1892],
#  [2011041108106,
#   'Klaveness, Thv.',
#   'Forklaring over Luthers lille katekisme',
#   1931],
#  [2009020400112,
#   'Sverdrup, J.R.',
#   'Forklaring over Luthers lille katekisme',
#   1896],
#  [2010062806089,
#   'Klaveness, Thv.',
#   'Forklaring over Luthers lille katekisme',
#   1912],
#  [2014031808015,
#   'Pontoppidan, Erik',
#   'Forklaring over Luthers lille Katekisme',
#   1903],
#  [2010110206042,
#   'Klaveness, Thv.',
#   'Forklaring over Luthers lille katekisme',
#   1920],
#  [2009012800116,
#   'Klaveness, Thv.',
#   'Forklaring over Luthers lille katekisme',
#   1894],
#  [2012042512004,
#   'Sverdrup, J.R.',
#   'Forklaring over Luthers lille katekisme',
#   1927],
#  [2012051808185,
#   'Pontoppidan, Erik',
#   'Forklaring over Luthers lille katekisme',
#   1900],
#  [2011112508170, '', 'Forklaring over Luthers lille katekisme', 1955],
#  [2012031308054,
#   'Westrum, G.',
#   'Forklaring over Luthers lille katekisme',
#   1900],
#  [2009120713003,
#   'Westrum, G.',
#   'Forklaring over Luthers lille katekisme',
#   1899],
#  [2009012800128,
#   'Klaveness, Thv.',
#   'Forklaring over Luthers lille katekisme',
#   1935],
#  [2009012800115,
#   'Sverdrup, J.R.',
#   'Forklaring over Luthers lille katekisme',
#   1907],
#  [2009012800137,
#   'Klaveness, Thv.',
#   'Forklaring over Luthers lille katekisme',
#   1892],
#  [2008091800039, '', 'Forklaring over Luthers lille katekisme', 1896],
#  [2008091800037,
#   'Sverdrup, H.U.',
#   'Forklaring over Luthers lille katekisme',
#   1893],
#  [2009013000088,
#   'Sverdrup, J.R.',
#   'Forklaring over Luthers lille katekisme',
#   1897],
#  [2012060412003,
#   'Pontoppidan, Erik',
#   'Forklaring over Luthers lille katekisme',
#   1909],
#  [2012111908201,
#   'Lunde, Nils',
#   'Forklaring over Luthers lille katekisme',
#   1911],
#  [2013061308015,
#   'Schønheyder, Lor. W.',
#   'Forklaring af Luthers lille Katekismus',
#   1885],
#  [2008091800004,
#   'Schønheyder, Lor. W.',
#   'Forklaring af Luthers lille katekismus',
#   1881],
#  [2012011008144,
#   'Klaveness, Thv.',
#   'Forklaring til Luthers lille katekisme',
#   1958],
#  [2012050708047,
#   'Klaveness, Thv.',
#   'Forklaring til Luthers lille katekisme',
#   1948],
#  [2008082100019,
#   'Sverdrup, J.R.',
#   'Forklaring til Luthers litle katekisma',
#   1904],
#  [2009013000087,
#   'Sverdrup, J.R.',
#   'Forklåring til Luthers litle katekisme',
#   1925],
#  [2010070605079,
#   'Klaveness, Thv.',
#   'Forklaring til Luthers litle katekisme',
#   1954],
#  [2007061501017,
#   'Klaveness, Thv.',
#   'Forklaring til Luthers litle katekisme',
#   1961],
#  [2012041808015,
#   'Sverdrup, J.R.',
#   'Forklaring til Luthers litle katekisme',
#   1901],
#  [2009012700047,
#   'Klaveness, Thv.',
#   'Forklaring til Luthers lille katekisme',
#   1940],
#  [2008111103028,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1853],
#  [2010081920015,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1899],
#  [2009060204074,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1862],
#  [2009072901014,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1860],
#  [2015012808010,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1846],
#  [2009072801110,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Catechismus',
#   1828],
#  [2009072901015,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1869],
#  [2016051048057,
#   'Dass, Petter',
#   'Dr. Marthin Luthers Lille Katechismus',
#   1888],
#  [2009072813014,
#   'Dass, Petter',
#   'Dr. Marthin Luthers Lille Katechismus',
#   1891],
#  [2009062304067,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1843],
#  [2013042608121,
#   'Luther, Martin',
#   'Dr. Martin Luthers større Katechismus',
#   1865],
#  [2009072801106,
#   'Klaveness, Thv.',
#   'Uttyding til Luthers litle katekisme',
#   1926],
#  [2009072801123,
#   'Klaveness, Thv.',
#   'Uttyding til Luthers litle katekisme',
#   1899],
#  [2010112406058,
#   'Aspås, Harald',
#   'Luthers katekismus som lærebok i dag',
#   1948],
#  [2009072801122,
#   'Klaveness, Thv.',
#   'Uttyding til Luthers litle katekisma',
#   1899],
#  [2010031003020,
#   'Luther, Martin',
#   'Dr. Morten Luther ucceb katekismusaš',
#   1837],
#  [2009060204078,
#   'Luther, Martin',
#   'Dr. Martin Luthers store Katechismus',
#   1881],
#  [2016060348142, 'Dass, Petter', 'Dr. Martin Luthers lille Katechismus', 1888],
#  [2015102626001, 'Dass, Petter', '[D. Mort. Luthers Lille Catechismus]', 1730],
#  [2010020103016,
#   'Luther, Martin',
#   'Dr. Morten Luthers liden Katechismus',
#   1844],
#  [2009072801111,
#   'Luther, Martin',
#   'Dr. Morten Luthers liden Katechismus',
#   1845],
#  [2009012700063,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus',
#   1924],
#  [2013110508239,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus',
#   1935],
#  [2016031148113,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus',
#   1915],
#  [2013100708174,
#   'Luther, Martin',
#   'Dr. Morten Luthers lille katekismus',
#   1883],
#  [2009012800030,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1928],
#  [2009012700061,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1932],
#  [2009012800135,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1932],
#  [2008061904123,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1907],
#  [2009012700062,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1908],
#  [2009020200121,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1891],
#  [2009030403046,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1895],
#  [2009012700057,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus',
#   1924],
#  [2016022548116,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus',
#   1933],
#  [2014060308106,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1924],
#  [2009012700056,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1928],
#  [2014120108160,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1924],
#  [2009020500046,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1917],
#  [2008041400050,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille katekismus',
#   1939],
#  [2012041808017,
#   'Luther, Martin',
#   'Dr. Martin Luthers lille Katekismus',
#   1890],
#  [2007030912001, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1722],
#  [2015080629001, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1744],
#  [2007110613001, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1777],
#  [2008090113001, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1750],
#  [2008082710004, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1761],
#  [2009010613002, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1794],
#  [2009010913004, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1742],
#  [2009010813002, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1788],
#  [2015102827002, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1765],
#  [2008021313001, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1753],
#  [2009022313001,
#   'Luther, Martin',
#   'D. Martin Luthers liden Catechismus',
#   1799],
#  [2015111826011, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1736],
#  [2016052528004, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1744],
#  [2008082510003, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1770],
#  [2009010613003, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1753],
#  [2015042828004, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1722],
#  [2015080427003, 'Dass, Petter', 'D. Morten Luthers Lille Catechismus', 1782],
#  [2011112808024, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1955],
#  [2016022308080, 'Luther, Martin', 'Dr. Martin Luthers litle katekisma', 1918],
#  [2009012700059, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1955],
#  [2013031108212, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1947],
#  [2012083008162, 'Luther, Martin', 'Dr. Martin Luthers litle katekisma', 1906],
#  [2008061800049, 'Luther, Martin', 'Katekismen etter Dr. Martin Luther', 1953],
#  [2009012800134, '', 'Dr. Martin Luthers lille katekisme', 1929],
#  [2013043005024, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1976],
#  [2016063008054, 'Luther, Martin', 'Dr. Martin Luthers litle katekisme', 1922],
#  [2015062208083, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1932],
#  [2009012700060, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1939],
#  [2012092705090, 'Luther, Martin', 'Katekismen etter Dr. Martin Luther', 1946],
#  [2013072508068, '', 'Dr. Martin Luthers lille katekisme', 1940],
#  [2012041808018, 'Luther, Martin', 'Dr. Martin Luthers litle katekisme', 1929],
#  [2014031208152, 'Luther, Martin', 'Dr. Martin Luthers litle katekisme', 1964],
#  [2014041108110, 'Luther, Martin', 'Dr. Martin Luthers litle katekisma', 1922],
#  [2009012700049, 'Luther, Martin', 'Katekismen etter Dr. Martin Luther', 1938],
#  [2009020200119, 'Luther, Martin', 'Dr. Martin Luthers litle katekisma', 1891],
#  [2013031108211, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1967],
#  [2009012700054, 'Luther, Martin', 'Dr. Martin Luthers litle katekisme', 1955],
#  [2009012700053, 'Luther, Martin', 'Dr. Martin Luthers litle katekisme', 1942],
#  [2013101706000, 'Luther, Martin', 'Katekismen efter Dr. Martin Luther', 1938],
#  [2016030808037, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1926],
#  [2016020108003, 'Luther, Martin', 'Dr. Martin Luthers litle katekisma', 1912],
#  [2012081008182, 'Luther, Martin', 'Katekismen etter Dr. Martin Luther', 1963],
#  [2009012800001, '', 'Dr. Martin Luthers lille katekisme', 1925],
#  [2009012700058, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1939],
#  [2012050708144, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1944],
#  [2016011948040, 'Luther, Martin', 'Dr. Martin Luthers lille katekisme', 1941],
#  [2010091503019, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1999],
#  [2007041111001, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1721],
#  [2009010610004, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1736],
#  [2009012112002, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1727],
#  [2009012212001, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1715],
#  [2007100810001, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1736],
#  [2009010813003, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1732],
#  [2016012026002, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1750],
#  [2015102828002, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1734],
#  [2015042026002, 'Dass, Petter', 'D. Mort. Luthers Lille Catechismus', 1734],
#  [2013072508067, 'Luther, Martin', 'Katekisma etter dr. Martin Luther', 1940],
#  [2009012700043, 'Luther, Martin', 'Katekisma etter dr. Martin Luther', 1953],
#  [2011112308092, 'Luther, Martin', 'Dr.Martin Luthers lille katekisme', 1954],
#  [2011030912001, 'Luther, Martin', 'Dr.Martin Luthers lille katekisme', 1950],
#  [2010021803046, 'Luther, Martin', 'Doktor Morten Luthers Katechismus', 1853],
#  [2016060348005, 'Luther, Martin', "Martin Luther's store katekismus", 1958],
#  [2014102108239, 'Luther, Martin', 'Dr. M. Luther ucca katekismusas̉', 1927],
#  [2014102226003, 'Dass, Petter', 'Dr. M. Luthers lille Catechismus', 1845],
#  [2011112308211, 'Luther, Martin', "Martin Luther's store katekisme", 1952],
#  [2008091800031, 'Amundsen, G..', 'Dr. M. Luthers lille Katekismus', 1884],
#  [2008091701019, 'Luther, Martin', 'Martin Luthers lille katekisme', 1997],
#  [2013073008019, 'Luther, Martin', 'Martin Luthers lille katekisme', 2012],
#  [2009020600128, 'Luther, Martin', 'Martin Luthers litle Katekisma', 1868],
#  [2014111808110, 'Luther, Martin', 'Martin Luthers store katekisme', 1996],
#  [2016022548118, 'Luther, Martin', 'Dr. M. Luthers litle katekisme', 1918],
#  [2013121805115, 'Luther, Martin', 'Martin Luthers vesle katekisme', 1977],
#  [2009012900011, 'Luther, Martin', 'Martin Luthers lille katekisme', 1979],
#  [2014052108066, 'Luther, Martin', 'Katekisma etter Martin Luther', 1940],
#  [2016052548035, 'Luther, Martin', 'Catechismus minor D.M. Luth', 1729],
#  [2015091028001, 'Luther, Martin', 'Luther utzeb Catechismus', 1776],
#  [2013010308194, 'Pontoppidan, Erik', 'Luthers lille katekisme', 1894],
#  [2011111708168, 'Luther, Martin', 'Luthers lille katekisme', 1953],
#  [2009012700042, 'Luther, Martin', 'Luthers lille katekisme', 1941],
#  [2015061508071, '', 'Luthers store katekisme', 1995],
#  [2015112708148, 'Nebe, A.', 'Luthers lille katekisme', 1904],
#  [2013100708167, 'Tananger, T.', 'Luthers lille katekisme', 1910],
#  [2009032603009, 'Pontoppidan, Erik', 'Luthers lille katekisme', 1897],
#  [2006081800047, 'Luther, Martin', 'Luthers katekismer', 1979]]

# %%
list(map(len, [x[2] for x in luther]))
# Out:
# [257,
#  219,
#  171,
#  171,
#  170,
#  157,
#  155,
#  155,
#  155,
#  155,
#  155,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  153,
#  152,
#  152,
#  146,
#  130,
#  130,
#  130,
#  129,
#  127,
#  127,
#  127,
#  127,
#  127,
#  126,
#  125,
#  125,
#  125,
#  125,
#  125,
#  124,
#  124,
#  122,
#  121,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  108,
#  105,
#  102,
#  95,
#  92,
#  90,
#  90,
#  90,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  88,
#  86,
#  79,
#  77,
#  76,
#  72,
#  69,
#  68,
#  68,
#  67,
#  66,
#  66,
#  64,
#  64,
#  64,
#  64,
#  60,
#  58,
#  56,
#  56,
#  56,
#  55,
#  55,
#  55,
#  54,
#  52,
#  51,
#  51,
#  50,
#  50,
#  49,
#  49,
#  48,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  46,
#  45,
#  45,
#  43,
#  42,
#  42,
#  41,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  40,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  33,
#  33,
#  33,
#  33,
#  33,
#  32,
#  32,
#  32,
#  31,
#  31,
#  30,
#  30,
#  30,
#  30,
#  30,
#  30,
#  30,
#  29,
#  27,
#  24,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  18]

# %%
luther_df['title_len'] = list(map(len, map(lambda x: x.split(), luther_df['title'])))

# %%
luther_year_len = luther_df[['year', 'title_len']]

# %%
luther_year_len.rolling(window=10).mean().plot(x='year')

# %%
bib = nb.book_corpus(title="%bibel%", period=(1100, 1920), limit=5000)

# %%
bib['len'] = title_len(bib)

# %%
bib[['year', 'len']].sort_values(by='year').rolling(window=10).mean().plot(x='year')

# %%
text = """Book titles have developed out of the historical first page (Hoek 1981 as cited in Genette 1997). Modern paratextual elements like title and subtitle, abstract and foreword, table of contents, and publishing information, all belonged in some variant to the first page of books for a certain period within the printing history, a period which ended in the 19th century, almost within the same time span across different national publishers and printing houses. Much of the information from the first page is catalogued as title in modern metadata practice. The title in bibliographies, as a cataloging feature, became shorter over time, a process that appears to be closely connected with publishing history, and the way books are organized materially and visually.The paratextual elements, partly developed from the first page, found their way into different areas of the book layout. Title and author on the front, publishing information on third page, with table of contents before the foreword, along with index at the end, and footnotes interspersed with the text. There is a grammar to the layout of books, constant across printing houses and practices. The shortening of titles may be seen in connection with how the book binding practice changed during the first half of the 19th century, when it became custom to publish books ready bound, together with a dust jacket, or just with a dust jacket, or box. The dust jacket itself contains paratextual elements that are not found elsewhere in the book, like illustrations and blurbs, although there is an overlap in content. In this paper, we will discuss and document the development of the first page, from the middle of 19th century and onwards. Specifically, how it has developed into several parts and functions, as alluded to above, and try to list as much as possible of the paratextual elements that go into a book, in addition to what emanated from the historical first page. One hypothesis to investigate is the parallel development of book binding practices with certain paratextual elements. We will also discuss paratext as metadata, how some of these elements may disappear with digital publishing, while reoccurring in different places within the digital codex. For example, the index is a hidden feature of digital books, and no longer an explicit textual element, while footnotes may be interactive elements of the book, similar to hyperlinks for bibliographic references. Our material consists of metadata from available repositories from different libraries, and the collection of digitized books from the National Library of Norway
"""

# %%
len(text.split())
# Out:
# 417

# %%
luther_df
# Out:
#                urn                     author  \
# 55   2016112829001  Bang, Christen Staphensøn
# 52   2016022629002  Bang, Christen Staphensøn
# 48   2015102229002  Bang, Christen Staphensøn
# 54   2015102229006  Bang, Christen Staphensøn
# 49   2015102229007  Bang, Christen Staphensøn
# 51   2015102229009  Bang, Christen Staphensøn
# 53   2015102229008  Bang, Christen Staphensøn
# 50   2015102229004  Bang, Christen Staphensøn
# 10   2015092829005  Bang, Christen Staphensøn
# 47   2015090327002  Bang, Christen Staphensøn
# 250  2009012212001               Dass, Petter
# 247  2007041111001               Dass, Petter
# 200  2007030912001               Dass, Petter
# 215  2015042828004               Dass, Petter
# 249  2009012112002               Dass, Petter
# 274  2016052548035             Luther, Martin
# 178  2015102626001               Dass, Petter
# 252  2009010813003               Dass, Petter
# 255  2015042026002               Dass, Petter
# 254  2015102828002               Dass, Petter
# 211  2015111826011               Dass, Petter
# 251  2007100810001               Dass, Petter
# 248  2009010610004               Dass, Petter
# 206  2009010913004               Dass, Petter
# 201  2015080629001               Dass, Petter
# 212  2016052528004               Dass, Petter
# 253  2016012026002               Dass, Petter
# 203  2008090113001               Dass, Petter
# 209  2008021313001               Dass, Petter
# 214  2009010613003               Dass, Petter
# ..             ...                        ...
# 106  2011102708029              Bang, A. Chr.
# 259  2011030912001             Luther, Martin
# 117  2008042200003           Magerøy, Nils H.
# 264  2011112308211             Luther, Martin
# 257  2009012700043             Luther, Martin
# 222  2008061800049             Luther, Martin
# 277  2011111708168             Luther, Martin
# 258  2011112308092             Luther, Martin
# 89   2010070506138             Sverdrup, J.R.
# 156  2010070605079            Klaveness, Thv.
# 219  2009012700059             Luther, Martin
# 217  2011112808024             Luther, Martin
# 236  2009012700054             Luther, Martin
# 139  2011112508170
# 152  2012011008144            Klaveness, Thv.
# 261  2016060348005             Luther, Martin
# 157  2007061501017            Klaveness, Thv.
# 241  2012081008182             Luther, Martin
# 231  2014031208152             Luther, Martin
# 235  2013031108211             Luther, Martin
# 224  2013043005024             Luther, Martin
# 271  2013121805115             Luther, Martin
# 272  2009012900011             Luther, Martin
# 283  2006081800047             Luther, Martin
# 124  2013030608057               Laache, N.J.
# 279  2015061508071
# 269  2014111808110             Luther, Martin
# 266  2008091701019             Luther, Martin
# 246  2010091503019               Dass, Petter
# 267  2013073008019             Luther, Martin
#
#                                                  title  year  title_len
# 55   Postilla Catechetica, Ded er: Doct. Martini Lu...  1650        108
# 52   [Postilla Catechetica, Ded er: Doct. Martini L...  1651        110
# 48   [Postilla Catechetica, Ded er: Doct. Martini L...  1652        110
# 54   [Postilla Catechetica, Ded er: Doct. Martini L...  1652        110
# 49   [Postilla Catechetica, Ded er: Doct. Martini L...  1653        110
# 51   [Postilla Catechetica, Ded er: Doct. Martini L...  1653        110
# 53   [Postilla Catechetica, Ded er: Doct. Martini L...  1653        110
# 50   [Postilla Catechetica, Ded er: Doct. Martini L...  1654        110
# 10   Postilla Catechetica, ded er: Doct. Martini Lu...  1657        155
# 47   [Postilla Catechetica, Ded er: Doct. Martini L...  1662        110
# 250                 D. Mort. Luthers Lille Catechismus  1715         34
# 247                 D. Mort. Luthers Lille Catechismus  1721         34
# 200                D. Morten Luthers Lille Catechismus  1722         35
# 215                D. Morten Luthers Lille Catechismus  1722         35
# 249                 D. Mort. Luthers Lille Catechismus  1727         34
# 274                        Catechismus minor D.M. Luth  1729         27
# 178               [D. Mort. Luthers Lille Catechismus]  1730         36
# 252                 D. Mort. Luthers Lille Catechismus  1732         34
# 255                 D. Mort. Luthers Lille Catechismus  1734         34
# 254                 D. Mort. Luthers Lille Catechismus  1734         34
# 211                D. Morten Luthers Lille Catechismus  1736         35
# 251                 D. Mort. Luthers Lille Catechismus  1736         34
# 248                 D. Mort. Luthers Lille Catechismus  1736         34
# 206                D. Morten Luthers Lille Catechismus  1742         35
# 201                D. Morten Luthers Lille Catechismus  1744         35
# 212                D. Morten Luthers Lille Catechismus  1744         35
# 253                 D. Mort. Luthers Lille Catechismus  1750         34
# 203                D. Morten Luthers Lille Catechismus  1750         35
# 209                D. Morten Luthers Lille Catechismus  1753         35
# 214                D. Morten Luthers Lille Catechismus  1753         35
# ..                                                 ...   ...        ...
# 106    Forklaring over Dr. M. Luthers lille katekismus  1950         47
# 259                  Dr.Martin Luthers lille katekisme  1950         33
# 117         Leidetråd i Martin Luthers litle katekisme  1950         42
# 264                    Martin Luther's store katekisme  1952         31
# 257                  Katekisma etter dr. Martin Luther  1953         33
# 222                 Katekismen etter Dr. Martin Luther  1953         34
# 277                            Luthers lille katekisme  1953         23
# 258                  Dr.Martin Luthers lille katekisme  1954         33
# 89   Sverdrups forklåring til katekisma etter dr. M...  1954         58
# 156             Forklaring til Luthers litle katekisme  1954         38
# 219                 Dr. Martin Luthers lille katekisme  1955         34
# 217                 Dr. Martin Luthers lille katekisme  1955         34
# 236                 Dr. Martin Luthers litle katekisme  1955         34
# 139            Forklaring over Luthers lille katekisme  1955         39
# 152             Forklaring til Luthers lille katekisme  1958         38
# 261                   Martin Luther's store katekismus  1958         32
# 157             Forklaring til Luthers litle katekisme  1961         38
# 241                 Katekismen etter Dr. Martin Luther  1963         34
# 231                 Dr. Martin Luthers litle katekisme  1964         34
# 235                 Dr. Martin Luthers lille katekisme  1967         34
# 224                 Dr. Martin Luthers lille katekisme  1976         34
# 271                     Martin Luthers vesle katekisme  1977         30
# 272                     Martin Luthers lille katekisme  1979         30
# 283                                 Luthers katekismer  1979         18
# 124           Forklaring over Luthers lille katekismus  1982         40
# 279                            Luthers store katekisme  1995         23
# 269                     Martin Luthers store katekisme  1996         30
# 266                     Martin Luthers lille katekisme  1997         30
# 246                 D. Mort. Luthers Lille Catechismus  1999         34
# 267                     Martin Luthers lille katekisme  2012         30
#
# [284 rows x 5 columns]

# %%
nb.urn_concordance(word='paratekst', urns=urns, before=10, after=10)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032206046?searchText=paratekst' target='_blank' style='text-decoration:none'>(Sic), Røssaak, Eivind, 2001</a>
#                 </td>
#                 <td>I 1982 lanserte Genette ordet «</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>» som en betegnelse på litteraturens snittflater :</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032206046?searchText=paratekst' target='_blank' style='text-decoration:none'>(Sic), Røssaak, Eivind, 2001</a>
#                 </td>
#                 <td>None</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>: en tittel , en undertittel , mellomtider , forord</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032206046?searchText=paratekst' target='_blank' style='text-decoration:none'>(Sic), Røssaak, Eivind, 2001</a>
#                 </td>
#                 <td>eller følgesvenner . Her lanseres et utvidet begrep om «</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>» : « informasjoner som gjør teksten synlig for oss</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032206046?searchText=paratekst' target='_blank' style='text-decoration:none'>(Sic), Røssaak, Eivind, 2001</a>
#                 </td>
#                 <td>None</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>( av gr . para « ved siden av »</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032206046?searchText=paratekst' target='_blank' style='text-decoration:none'>(Sic), Røssaak, Eivind, 2001</a>
#                 </td>
#                 <td>Offentlig</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>, såkalt epitekst , dvs. relevante tekster publisert utenfor (</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070708147?searchText=paratekst' target='_blank' style='text-decoration:none'>Nyheten som hypertekst, Engebretsen, Martin, 2001</a>
#                 </td>
#                 <td>hvordan fotografienes status og relasjonen mellom bilde , brødtekst og</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>har utviklet seg gjennom de seneste tiår mot en stadig</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070708147?searchText=paratekst' target='_blank' style='text-decoration:none'>Nyheten som hypertekst, Engebretsen, Martin, 2001</a>
#                 </td>
#                 <td>innholdsstrukturen i lengre tekster representert verbalt vha ulike former for</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>; innholdsfortegnelser , indekser , titler , ingresser etc. ~</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070708147?searchText=paratekst' target='_blank' style='text-decoration:none'>Nyheten som hypertekst, Engebretsen, Martin, 2001</a>
#                 </td>
#                 <td>i fremstillingen av bestemte informasjonsstrukturer . I stedet for verbal</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>benyttes her en sammensetning av firkanter ( " blokker "</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070708147?searchText=paratekst' target='_blank' style='text-decoration:none'>Nyheten som hypertekst, Engebretsen, Martin, 2001</a>
#                 </td>
#                 <td>Om begrepet</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>, se Genette 1992 [ 1987 ] , Frandsen 1991.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070708147?searchText=paratekst' target='_blank' style='text-decoration:none'>Nyheten som hypertekst, Engebretsen, Martin, 2001</a>
#                 </td>
#                 <td>Frandsen , F . ( 1991 ) " Avisens</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>- et nyt område for medieforskningen " i Mediekultur nr.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013080508183?searchText=paratekst' target='_blank' style='text-decoration:none'>I møte mellom ord og bilde, Lykke, Jon, 2000</a>
#                 </td>
#                 <td>Genettes kartlegging av tekstlige forbindelser er illustrasjonen plassert under begrepet</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>, som han karakteriserer på følgende måte :</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013080508183?searchText=paratekst' target='_blank' style='text-decoration:none'>I møte mellom ord og bilde, Lykke, Jon, 2000</a>
#                 </td>
#                 <td>ulike kategoriene . Og nettopp plasseringen av illustrasjonene innenfor kategorien</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>kan problematiseres . Hos Genette blir de en del av</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013080508183?searchText=paratekst' target='_blank' style='text-decoration:none'>I møte mellom ord og bilde, Lykke, Jon, 2000</a>
#                 </td>
#                 <td>den illustrerte teksten . Dermed flyttes oppmerksomheten fra illustrasjonene som</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>, som handler om " [ ... ] the literary</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015102708061?searchText=paratekst' target='_blank' style='text-decoration:none'>Smerten, harmen - og kunstens smil, Aarset, Hans Erik, 2001</a>
#                 </td>
#                 <td>til at Duras , i en kort introduserende og forklarende</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>, både utlegger den enigmatiske tittelen og « setter »</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011031405042?searchText=paratekst' target='_blank' style='text-decoration:none'>Marginalia, Mæleng, Per, 2001</a>
#                 </td>
#                 <td>og ikke isteden har valgt for eksempel usynlig tekst ,</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>eller mellomtekst , eller teksten mellom linjene , har det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060106039?searchText=paratekst' target='_blank' style='text-decoration:none'>Fire blikk på sakprosaen, , 2001</a>
#                 </td>
#                 <td>leseren vil i brødteksten finne en relativt nøktern under- eller</td>
#                 <td>paratekst</td>
#                 <td style='text-align:left'>som lyder slik : Det er mulig at man kan</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014051405013?searchText=paratekst' target='_blank' style='text-decoration:none'>Nyheten som hypertekst, Engebretsen, Martin, 2001</a>
#                 </td>
#                 <td>hvordan fotografienes status og relasjonen mellom bilde , brødtekst og</td>
#                 <td>p
